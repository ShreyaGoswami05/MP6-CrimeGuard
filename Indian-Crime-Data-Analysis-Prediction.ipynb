# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
crime = pd.read_csv(r"crime.csv")

# %%
crime
# Out:
#             STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     Andhra Pradesh     ADILABAD  2013      96                 72
# 1     Andhra Pradesh    ANANTAPUR  2013     156                149
# 2     Andhra Pradesh     CHITTOOR  2013      72                 61
# 3     Andhra Pradesh     CUDDAPAH  2013      93                107
# 4     Andhra Pradesh    CYBERABAD  2013     162                123
# ...              ...          ...   ...     ...                ...
# 9835        DELHI UT         WEST  2001      70                 51
# 9836     LAKSHADWEEP  LAKSHADWEEP  2001       1                  0
# 9837     LAKSHADWEEP        TOTAL  2001       1                  0
# 9838      PUDUCHERRY  PONDICHERRY  2001      25                 32
# 9839      PUDUCHERRY        TOTAL  2001      25                 32
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                            13    61               0
# 1                                             3    28               0
# 2                                             2    31               0
# 3                                             7    19               0
# 4                                            16   138               0
# ...                                         ...   ...             ...
# 9835                                         12    45               0
# 9836                                          0     0               0
# 9837                                          0     0               0
# 9838                                          1     9               0
# 9839                                          1     9               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0             61                      65  ...     30                2394
# 1             28                     110  ...     29                2537
# 2             31                      52  ...     18                 937
# 3             19                      84  ...     34                2310
# 4            138                     192  ...     40                4284
# ...          ...                     ...  ...    ...                 ...
# 9835          45                     151  ...      3                 252
# 9836           0                       0  ...      2                   3
# 9837           0                       0  ...      2                   3
# 9838           9                       4  ...     31                 635
# 9839           9                       4  ...     31                 635
#
#       DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0               12                                                197
# 1               23                                                337
# 2               13                                                119
# 3                9                                                318
# 4               43                                                350
# ...            ...                                                ...
# 9835            18                                                 65
# 9836             0                                                  0
# 9837             0                                                  0
# 9838             1                                                 35
# 9839             1                                                 35
#
#       INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                            138                                  464
# 1                             43                                  161
# 2                             84                                  435
# 3                            163                                  207
# 4                            338                                 1526
# ...                          ...                                  ...
# 9835                           2                                   22
# 9836                           0                                    0
# 9837                           0                                    0
# 9838                          27                                    3
# 9839                          27                                    3
#
#       IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 9835                                            0
# 9836                                            0
# 9837                                            0
# 9838                                            0
# 9839                                            0
#
#       CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0                             376              1390              6381
# 1                             573              1634              6913
# 2                             546              2239              5610
# 3                             464              1741              7048
# 4                            1104              3139             19992
# ...                           ...               ...               ...
# 9835                            4              4151              7690
# 9836                            0                17                36
# 9837                            0                17                36
# 9838                          166              2324              4068
# 9839                          166              2324              4068
#
# [9840 rows x 33 columns]

# %%
crime.head()
# Out:
#          STATE/UT   DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  Andhra Pradesh   ADILABAD  2013      96                 72
# 1  Andhra Pradesh  ANANTAPUR  2013     156                149
# 2  Andhra Pradesh   CHITTOOR  2013      72                 61
# 3  Andhra Pradesh   CUDDAPAH  2013      93                107
# 4  Andhra Pradesh  CYBERABAD  2013     162                123
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         13    61               0
# 1                                          3    28               0
# 2                                          2    31               0
# 3                                          7    19               0
# 4                                         16   138               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          61                      65  ...     30                2394
# 1          28                     110  ...     29                2537
# 2          31                      52  ...     18                 937
# 3          19                      84  ...     34                2310
# 4         138                     192  ...     40                4284
#
#    DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0            12                                                197
# 1            23                                                337
# 2            13                                                119
# 3             9                                                318
# 4            43                                                350
#
#    INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                         138                                  464
# 1                          43                                  161
# 2                          84                                  435
# 3                         163                                  207
# 4                         338                                 1526
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                          376
# 1                                            0                          573
# 2                                            0                          546
# 3                                            0                          464
# 4                                            0                         1104
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0              1390              6381
# 1              1634              6913
# 2              2239              5610
# 3              1741              7048
# 4              3139             19992
#
# [5 rows x 33 columns]

# %%
crime.tail()
# Out:
#          STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 9835     DELHI UT         WEST  2001      70                 51
# 9836  LAKSHADWEEP  LAKSHADWEEP  2001       1                  0
# 9837  LAKSHADWEEP        TOTAL  2001       1                  0
# 9838   PUDUCHERRY  PONDICHERRY  2001      25                 32
# 9839   PUDUCHERRY        TOTAL  2001      25                 32
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 9835                                         12    45               0
# 9836                                          0     0               0
# 9837                                          0     0               0
# 9838                                          1     9               0
# 9839                                          1     9               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 9835          45                     151  ...      3                 252
# 9836           0                       0  ...      2                   3
# 9837           0                       0  ...      2                   3
# 9838           9                       4  ...     31                 635
# 9839           9                       4  ...     31                 635
#
#       DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 9835            18                                                 65
# 9836             0                                                  0
# 9837             0                                                  0
# 9838             1                                                 35
# 9839             1                                                 35
#
#       INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 9835                           2                                   22
# 9836                           0                                    0
# 9837                           0                                    0
# 9838                          27                                    3
# 9839                          27                                    3
#
#       IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# 9835                                            0
# 9836                                            0
# 9837                                            0
# 9838                                            0
# 9839                                            0
#
#       CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES
# 9835                            4              4151              7690
# 9836                            0                17                36
# 9837                            0                17                36
# 9838                          166              2324              4068
# 9839                          166              2324              4068
#
# [5 rows x 33 columns]

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
#  8   OTHER RAPE                                           9840 non-null   int64
#  9   KIDNAPPING & ABDUCTION                               9840 non-null   int64
#  10  KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS          9840 non-null   int64
#  11  KIDNAPPING AND ABDUCTION OF OTHERS                   9840 non-null   int64
#  12  DACOITY                                              9840 non-null   int64
#  13  PREPARATION AND ASSEMBLY FOR DACOITY                 9840 non-null   int64
#  14  ROBBERY                                              9840 non-null   int64
#  15  BURGLARY                                             9840 non-null   int64
#  16  THEFT                                                9840 non-null   int64
#  17  AUTO THEFT                                           9840 non-null   int64
#  18  OTHER THEFT                                          9840 non-null   int64
#  19  RIOTS                                                9840 non-null   int64
#  20  CRIMINAL BREACH OF TRUST                             9840 non-null   int64
#  21  CHEATING                                             9840 non-null   int64
#  22  COUNTERFIETING                                       9840 non-null   int64
#  23  ARSON                                                9840 non-null   int64
#  24  HURT/GREVIOUS HURT                                   9840 non-null   int64
#  25  DOWRY DEATHS                                         9840 non-null   int64
#  26  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  9840 non-null   int64
#  27  INSULT TO MODESTY OF WOMEN                           9840 non-null   int64
#  28  CRUELTY BY HUSBAND OR HIS RELATIVES                  9840 non-null   int64
#  29  IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES          9840 non-null   int64
#  30  CAUSING DEATH BY NEGLIGENCE                          9840 non-null   int64
#  31  OTHER IPC CRIMES                                     9840 non-null   int64
#  32  TOTAL IPC CRIMES                                     9840 non-null   int64
# dtypes: int64(31), object(2)
# memory usage: 2.5+ MB

# %%
crime.isna().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# THEFT                                                  0
# AUTO THEFT                                             0
# OTHER THEFT                                            0
# RIOTS                                                  0
# CRIMINAL BREACH OF TRUST                               0
# CHEATING                                               0
# COUNTERFIETING                                         0
# ARSON                                                  0
# HURT/GREVIOUS HURT                                     0
# DOWRY DEATHS                                           0
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY    0
# INSULT TO MODESTY OF WOMEN                             0
# CRUELTY BY HUSBAND OR HIS RELATIVES                    0
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES            0
# CAUSING DEATH BY NEGLIGENCE                            0
# OTHER IPC CRIMES                                       0
# TOTAL IPC CRIMES                                       0
# dtype: int64

# %%
crime.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
# convert the STATE/UT and DISTRICT columns to uppercase
crime['STATE/UT'] = crime['STATE/UT'].str.upper()
crime['DISTRICT'] = crime['DISTRICT'].str.upper()

# %%
crime['STATE/UT'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A&N ISLANDS', 'CHANDIGARH', 'D&N HAVELI',
#        'DAMAN & DIU', 'DELHI UT', 'LAKSHADWEEP', 'PUDUCHERRY',
#        'A & N ISLANDS', 'D & N HAVELI'], dtype=object)

# %%
def state(name):
    state = crime.groupby(['STATE/UT','DISTRICT','YEAR']).sum()['TOTAL IPC CRIMES']
    return state[name]

# %%
state('MAHARASHTRA')
# Out:
# DISTRICT    YEAR
# AHMEDNAGAR  2001      4391
#             2002      4506
#             2003      4251
#             2004      4738
#             2005      5241
#                      ...
# YAVATMAL    2010      4777
#             2011      5008
#             2012      6365
#             2013     12567
# ZZ TOTAL    2013    234385
# Name: TOTAL IPC CRIMES, Length: 598, dtype: int64

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
#  8   OTHER RAPE                                           9840 non-null   int64
#  9   KIDNAPPING & ABDUCTION                               9840 non-null   int64
#  10  KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS          9840 non-null   int64
#  11  KIDNAPPING AND ABDUCTION OF OTHERS                   9840 non-null   int64
#  12  DACOITY                                              9840 non-null   int64
#  13  PREPARATION AND ASSEMBLY FOR DACOITY                 9840 non-null   int64
#  14  ROBBERY                                              9840 non-null   int64
#  15  BURGLARY                                             9840 non-null   int64
#  16  THEFT                                                9840 non-null   int64
#  17  AUTO THEFT                                           9840 non-null   int64
#  18  OTHER THEFT                                          9840 non-null   int64
#  19  RIOTS                                                9840 non-null   int64
#  20  CRIMINAL BREACH OF TRUST                             9840 non-null   int64
#  21  CHEATING                                             9840 non-null   int64
#  22  COUNTERFIETING                                       9840 non-null   int64
#  23  ARSON                                                9840 non-null   int64
#  24  HURT/GREVIOUS HURT                                   9840 non-null   int64
#  25  DOWRY DEATHS                                         9840 non-null   int64
#  26  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  9840 non-null   int64
#  27  INSULT TO MODESTY OF WOMEN                           9840 non-null   int64
#  28  CRUELTY BY HUSBAND OR HIS RELATIVES                  9840 non-null   int64
#  29  IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES          9840 non-null   int64
#  30  CAUSING DEATH BY NEGLIGENCE                          9840 non-null   int64
#  31  OTHER IPC CRIMES                                     9840 non-null   int64
#  32  TOTAL IPC CRIMES                                     9840 non-null   int64
# dtypes: int64(31), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# # Statistical Data Analysis

# %%
import math
import statistics
import scipy.stats as stats

# %% [markdown]
# # 1. Descriptive Statistics

# %%
crime.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9840.000000  9840.000000     9840.000000
# mean                                    9.754878    55.456098        0.005488
# std                                    58.733349   201.690457        0.111218
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# 50%                                     2.000000    21.000000        0.000000
# 75%                                     6.000000    43.000000        0.000000
# max                                  1616.000000  4335.000000        5.000000
#
#         OTHER RAPE  KIDNAPPING & ABDUCTION  \
# count  9840.000000             9840.000000
# mean     55.450610               85.836992
# std     201.676202              354.035359
# min       0.000000                0.000000
# 25%       8.000000               10.000000
# 50%      21.000000               26.000000
# 75%      43.000000               60.000000
# max    4335.000000            11183.000000
#
#        KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# count                                  9840.000000
# mean                                     64.184553
# std                                     278.536450
# min                                       0.000000
# 25%                                       6.000000
# 50%                                      19.000000
# 75%                                      46.000000
# max                                    9737.000000
#
#        KIDNAPPING AND ABDUCTION OF OTHERS  ...        ARSON  \
# count                         9840.000000  ...  9840.000000
# mean                            21.652439  ...    25.012398
# std                             93.769371  ...    97.601717
# min                              0.000000  ...     0.000000
# 25%                              2.000000  ...     2.000000
# 50%                              5.000000  ...     8.000000
# 75%                             14.000000  ...    19.000000
# max                           2685.000000  ...  2830.000000
#
#        HURT/GREVIOUS HURT  DOWRY DEATHS  \
# count         9840.000000   9840.000000
# mean           753.362805     20.179878
# std           3059.322654     97.446611
# min              0.000000      0.000000
# 25%             43.750000      1.000000
# 50%            199.000000      5.000000
# 75%            533.250000     16.000000
# max          60488.000000   2335.000000
#
#        ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# count                                        9840.000000
# mean                                          106.482520
# std                                           423.729483
# min                                             0.000000
# 25%                                            10.000000
# 50%                                            33.000000
# 75%                                            80.000000
# max                                          8252.000000
#
#        INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# count                 9840.000000                          9840.000000
# mean                    27.772967                           202.046138
# std                    170.367098                           869.325453
# min                      0.000000                             0.000000
# 25%                      0.000000                            11.000000
# 50%                      2.000000                            49.000000
# 75%                     13.000000                           139.250000
# max                   4970.000000                         19865.000000
#
#        IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# count                                  9840.000000
# mean                                      0.187602
# std                                       2.319261
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                      83.000000
#
#        CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES
# count                  9840.000000       9840.000000       9840.000000
# mean                    226.296951       2214.523171       5404.141463
# std                     952.900601       8199.391921      18941.271529
# min                       0.000000          0.000000          0.000000
# 25%                       5.000000        264.000000        857.750000
# 50%                      70.000000        750.000000       2130.500000
# 75%                     180.000000       1631.000000       4025.000000
# max                   16076.000000     127850.000000     234385.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# # 1.3 Measure of Shape

# %% [markdown]
# # Skewness

# %% [markdown]
# Skewness is a measure of the asymmetry of a probability distribution, which indicates whether the data is symmetric or skewed to one side. In other words, it measures the degree of deviation of a distribution from a normal or bell-shaped curve.

# %%
crime.select_dtypes(include=['number']).skew()
# Out:
# YEAR                                                   -0.052110
# MURDER                                                 10.586544
# ATTEMPT TO MURDER                                      11.216619
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              20.356354
# RAPE                                                    9.939488
# CUSTODIAL RAPE                                         32.660692
# OTHER RAPE                                              9.940215
# KIDNAPPING & ABDUCTION                                 13.355613
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            15.426410
# KIDNAPPING AND ABDUCTION OF OTHERS                     13.111622
# DACOITY                                                12.606410
# PREPARATION AND ASSEMBLY FOR DACOITY                   17.108085
# ROBBERY                                                15.172991
# BURGLARY                                               10.412429
# THEFT                                                   9.383886
# AUTO THEFT                                              9.760274
# OTHER THEFT                                            10.190863
# RIOTS                                                   9.932250
# CRIMINAL BREACH OF TRUST                               12.998842
# CHEATING                                               13.028966
# COUNTERFIETING                                         10.885885
# ARSON                                                  11.238736
# HURT/GREVIOUS HURT                                     10.262287
# DOWRY DEATHS                                           15.366043
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY    10.851155
# INSULT TO MODESTY OF WOMEN                             17.070756
# CRUELTY BY HUSBAND OR HIS RELATIVES                    11.874988
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES            20.602969
# CAUSING DEATH BY NEGLIGENCE                            10.711569
# OTHER IPC CRIMES                                        9.006755
# TOTAL IPC CRIMES                                        7.993151
# dtype: float64

# %%
crime['THEFT'].plot(kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(crime['YEAR'],hist=True,kde=True)
# Out:
# <Axes: xlabel='YEAR', ylabel='Density'>

# %%
sns.displot(crime, x="THEFT", hue="YEAR", kind="kde", multiple="stack")

# %% [markdown]
# # Kurtosis

# %% [markdown]
# Kurtosis is a measure of the "peakedness" or "flatness" of a probability distribution, which describes how much of the distribution is concentrated around the central point, and how much is spread out towards the tails.
#
# A distribution with high kurtosis has a very sharp peak and heavy tails, indicating that it has more outliers and is more prone to extreme values. A distribution with low kurtosis is more flat-topped and has lighter tails, indicating that it has fewer outliers and is more stable.

# %%
crime.select_dtypes(include=['number']).kurtosis()
# Out:
# YEAR                                                     -1.220315
# MURDER                                                  144.991758
# ATTEMPT TO MURDER                                       165.067686
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               476.482702
# RAPE                                                    123.144254
# CUSTODIAL RAPE                                         1323.871144
# OTHER RAPE                                              123.164405
# KIDNAPPING & ABDUCTION                                  253.981863
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             348.619391
# KIDNAPPING AND ABDUCTION OF OTHERS                      232.755005
# DACOITY                                                 204.169477
# PREPARATION AND ASSEMBLY FOR DACOITY                    382.120594
# ROBBERY                                                 388.368214
# BURGLARY                                                135.563460
# THEFT                                                   111.746370
# AUTO THEFT                                              119.570356
# OTHER THEFT                                             134.054995
# RIOTS                                                   113.399875
# CRIMINAL BREACH OF TRUST                                223.816347
# CHEATING                                                230.448403
# COUNTERFIETING                                          146.564929
# ARSON                                                   178.564555
# HURT/GREVIOUS HURT                                      125.372525
# DOWRY DEATHS                                            291.725554
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY     143.111526
# INSULT TO MODESTY OF WOMEN                              357.151303
# CRUELTY BY HUSBAND OR HIS RELATIVES                     180.369986
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES             513.224370
# CAUSING DEATH BY NEGLIGENCE                             130.855770
# OTHER IPC CRIMES                                         93.580059
# TOTAL IPC CRIMES                                         68.842992
# dtype: float64

# %%
fig, ax = plt.subplots()
ax.hist(crime["MURDER"], bins=20)
ax.set_title("Histogram of MURDER")
ax.set_xlabel("Number of Murders")
ax.set_ylabel("Frequency")
plt.show()

# %%
plt.boxplot(crime["MURDER"])
plt.title("Kurtosis plot of MURDER")
plt.xlabel("MURDER")
plt.show()

# %% [markdown]
# By looking at the histogram and boxplot, we can get an idea of the kurtosis of the "MURDER" variable. A high peak in the histogram and a small box in the boxplot indicate a high kurtosis, while a more spread-out histogram and a larger box indicate a low kurtosis.

# %% [markdown]
# # Data visualization

# %%
plt.figure(figsize=(15,8))
state = crime.groupby('YEAR')
plt.pie(state.mean()['TOTAL IPC CRIMES'],labels=state.mean().index, 
        startangle=90,shadow=True,textprops={'fontsize':10,'c':'g'},
        autopct='%0.2f%%')

plt.title('CRIME in INDIA')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'ANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL ... PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & ... PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA ... NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTRIPURATRIPURATRIPURATRIPURATRIPURAUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALA & N ISLANDSA & N ISLANDSA & N ISLANDSCHANDIGARHCHANDIGARHD & N HAVELID & N HAVELIDAMAN & DIUDAMAN & DIUDAMAN & DIUDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTLAKSHADWEEPLAKSHADWEEPPUDUCHERRYPUDUCHERRY'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 plt.figure(figsize=(15,8))
#       2 state = crime.groupby('YEAR')
# ----> 3 plt.pie(state.mean()['TOTAL IPC CRIMES'],labels=state.mean().index,
#       4         startangle=90,shadow=True,textprops={'fontsize':10,'c':'g'},
#       5         autopct='%0.2f%%')
#       7 plt.title('CRIME in INDIA')
#       8 plt.show()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1503, in BlockManager.grouped_reduce(self, func)
#    1499 if blk.is_object:
#    1500     # split on object-dtype blocks bc some columns may raise
#    1501     #  while others do not.
#    1502     for sb in blk._split():
# -> 1503         applied = sb.apply(func)
#    1504         result_blocks = extend_blocks(applied, result_blocks)
#    1505 else:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert ANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHANDHRA PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL PRADESHARUNACHAL ... PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHHIMACHAL PRADESHJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & KASHMIRJAMMU & ... PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA PRADESHMADHYA ... NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTRIPURATRIPURATRIPURATRIPURATRIPURAUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTAR PRADESHUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDUTTARAKHANDWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALWEST BENGALA & N ISLANDSA & N ISLANDSA & N ISLANDSCHANDIGARHCHANDIGARHD & N HAVELID & N HAVELIDAMAN & DIUDAMAN & DIUDAMAN & DIUDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTDELHI UTLAKSHADWEEPLAKSHADWEEPPUDUCHERRYPUDUCHERRY to numeric

# %%
crime_totals = crime[['MURDER', 'RAPE', 'KIDNAPPING & ABDUCTION', 'ROBBERY', 'BURGLARY', 'THEFT']].sum()

# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(crime_totals.values, labels=crime_totals.index, autopct='%1.1f%%')
plt.title('Proportion of Crimes by Type')
plt.show()

# %%
# Group the data by state/union territory and sum the total number of IPC crimes
state_totals = crime.groupby('STATE/UT')['TOTAL IPC CRIMES'].sum()

# Create a bar chart
plt.figure(figsize=(15, 10))
plt.bar(state_totals.index, state_totals.values)
plt.xticks(rotation=90)
plt.xlabel('State/Union Territory')
plt.ylabel('Total IPC Crimes')
plt.title('Total IPC Crimes by State/Union Territory')
plt.show()

# %%
# Create a scatter plot of theft and burglary crimes
plt.figure(figsize=(12, 6))
plt.scatter(crime['THEFT'], crime['BURGLARY'])
plt.xlabel('Total Theft Crimes')
plt.ylabel('Total Burglary Crimes')
plt.title('Theft vs. Burglary Crimes')
plt.show()

# %% [markdown]
# # Correlation

# %% [markdown]
# In statistics, correlation is a measure of the strength and direction of the relationship between two variables. It indicates how closely the values of two variables are related to each other.
#
# The correlation matrix shows the correlation coefficients between each pair of variables. The correlation coefficient ranges between -1 and +1. A value of +1 indicates a perfect positive correlation, a value of 0 indicates no correlation, and a value of -1 indicates a perfect negative correlation.

# %%
crime.corr()
# Out:
#                                                         YEAR    MURDER  \
# YEAR                                                1.000000 -0.014588
# MURDER                                             -0.014588  1.000000
# ATTEMPT TO MURDER                                   0.002504  0.957058
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER          -0.007766  0.783331
# RAPE                                                0.042352  0.804640
# CUSTODIAL RAPE                                     -0.004074  0.147950
# OTHER RAPE                                          0.042357  0.804615
# KIDNAPPING & ABDUCTION                              0.074994  0.812158
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         0.087115  0.769808
# KIDNAPPING AND ABDUCTION OF OTHERS                  0.024376  0.779709
# DACOITY                                            -0.035842  0.790893
# PREPARATION AND ASSEMBLY FOR DACOITY                0.016628  0.422544
# ROBBERY                                             0.027788  0.810037
# BURGLARY                                           -0.011345  0.764318
# THEFT                                               0.022436  0.815590
# AUTO THEFT                                          0.065998  0.724088
# OTHER THEFT                                        -0.006905  0.817900
# RIOTS                                              -0.003357  0.753107
# CRIMINAL BREACH OF TRUST                            0.014599  0.883193
# CHEATING                                            0.052272  0.690684
# COUNTERFIETING                                      0.019869  0.721565
# ARSON                                              -0.015060  0.731055
# HURT/GREVIOUS HURT                                  0.006272  0.739870
# DOWRY DEATHS                                        0.008806  0.909064
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...  0.033599  0.722097
# INSULT TO MODESTY OF WOMEN                         -0.006613  0.645577
# CRUELTY BY HUSBAND OR HIS RELATIVES                 0.057645  0.709600
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES        -0.022344  0.312656
# CAUSING DEATH BY NEGLIGENCE                         0.041719  0.799893
# OTHER IPC CRIMES                                    0.024421  0.738281
# TOTAL IPC CRIMES                                    0.024087  0.847480
# CRIME_LEVEL                                         0.018724  0.805740
# STATE/UT_encoded                                   -0.005638 -0.001071
# DISTRICT_encoded                                    0.000089  0.168289
#
#                                                     ATTEMPT TO MURDER  \
# YEAR                                                         0.002504
# MURDER                                                       0.957058
# ATTEMPT TO MURDER                                            1.000000
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                    0.759504
# RAPE                                                         0.775656
# CUSTODIAL RAPE                                               0.122452
# OTHER RAPE                                                   0.775643
# KIDNAPPING & ABDUCTION                                       0.812462
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                  0.775176
# KIDNAPPING AND ABDUCTION OF OTHERS                           0.764913
# DACOITY                                                      0.710135
# PREPARATION AND ASSEMBLY FOR DACOITY                         0.385978
# ROBBERY                                                      0.779244
# BURGLARY                                                     0.709213
# THEFT                                                        0.760517
# AUTO THEFT                                                   0.689766
# OTHER THEFT                                                  0.753372
# RIOTS                                                        0.737645
# CRIMINAL BREACH OF TRUST                                     0.828155
# CHEATING                                                     0.686370
# COUNTERFIETING                                               0.669004
# ARSON                                                        0.693372
# HURT/GREVIOUS HURT                                           0.723744
# DOWRY DEATHS                                                 0.906619
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...           0.715919
# INSULT TO MODESTY OF WOMEN                                   0.593146
# CRUELTY BY HUSBAND OR HIS RELATIVES                          0.668873
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                  0.300088
# CAUSING DEATH BY NEGLIGENCE                                  0.773900
# OTHER IPC CRIMES                                             0.760012
# TOTAL IPC CRIMES                                             0.836367
# CRIME_LEVEL                                                  0.802921
# STATE/UT_encoded                                             0.029266
# DISTRICT_encoded                                             0.160100
#
#                                                     CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  \
# YEAR                                                                                -0.007766
# MURDER                                                                               0.783331
# ATTEMPT TO MURDER                                                                    0.759504
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                                            1.000000
# RAPE                                                                                 0.549934
# CUSTODIAL RAPE                                                                       0.071918
# OTHER RAPE                                                                           0.549933
# KIDNAPPING & ABDUCTION                                                               0.713369
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                                          0.710435
# KIDNAPPING AND ABDUCTION OF OTHERS                                                   0.583088
# DACOITY                                                                              0.477807
# PREPARATION AND ASSEMBLY FOR DACOITY                                                 0.381865
# ROBBERY                                                                              0.547693
# BURGLARY                                                                             0.377780
# THEFT                                                                                0.524334
# AUTO THEFT                                                                           0.522062
# OTHER THEFT                                                                          0.489730
# RIOTS                                                                                0.496281
# CRIMINAL BREACH OF TRUST                                                             0.797621
# CHEATING                                                                             0.495142
# COUNTERFIETING                                                                       0.532959
# ARSON                                                                                0.331825
# HURT/GREVIOUS HURT                                                                   0.351012
# DOWRY DEATHS                                                                         0.869477
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                                   0.437241
# INSULT TO MODESTY OF WOMEN                                                           0.511816
# CRUELTY BY HUSBAND OR HIS RELATIVES                                                  0.544761
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                                          0.164227
# CAUSING DEATH BY NEGLIGENCE                                                          0.515726
# OTHER IPC CRIMES                                                                     0.440495
# TOTAL IPC CRIMES                                                                     0.524913
# CRIME_LEVEL                                                                          0.507065
# STATE/UT_encoded                                                                     0.087459
# DISTRICT_encoded                                                                     0.093739
#
#                                                         RAPE  CUSTODIAL RAPE  \
# YEAR                                                0.042352       -0.004074
# MURDER                                              0.804640        0.147950
# ATTEMPT TO MURDER                                   0.775656        0.122452
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER           0.549934        0.071918
# RAPE                                                1.000000        0.128440
# CUSTODIAL RAPE                                      0.128440        1.000000
# OTHER RAPE                                          1.000000        0.127898
# KIDNAPPING & ABDUCTION                              0.757015        0.124048
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         0.744067        0.113345
# KIDNAPPING AND ABDUCTION OF OTHERS                  0.647978        0.131671
# DACOITY                                             0.619162        0.155955
# PREPARATION AND ASSEMBLY FOR DACOITY                0.522914        0.056040
# ROBBERY                                             0.750630        0.114576
# BURGLARY                                            0.796746        0.121511
# THEFT                                               0.797346        0.117500
# AUTO THEFT                                          0.732625        0.089261
# OTHER THEFT                                         0.783822        0.127442
# RIOTS                                               0.661206        0.124598
# CRIMINAL BREACH OF TRUST                            0.701468        0.123710
# CHEATING                                            0.681987        0.089173
# COUNTERFIETING                                      0.581220        0.086944
# ARSON                                               0.738478        0.114269
# HURT/GREVIOUS HURT                                  0.758538        0.117808
# DOWRY DEATHS                                        0.720330        0.113475
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...  0.902847        0.093410
# INSULT TO MODESTY OF WOMEN                          0.493752        0.064004
# CRUELTY BY HUSBAND OR HIS RELATIVES                 0.774559        0.096018
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES         0.244380        0.023984
# CAUSING DEATH BY NEGLIGENCE                         0.730924        0.115343
# OTHER IPC CRIMES                                    0.790613        0.104741
# TOTAL IPC CRIMES                                    0.860521        0.123094
# CRIME_LEVEL                                         0.805303        0.110029
# STATE/UT_encoded                                    0.000161       -0.018677
# DISTRICT_encoded                                    0.174504        0.036639
#
#                                                     OTHER RAPE  \
# YEAR                                                  0.042357
# MURDER                                                0.804615
# ATTEMPT TO MURDER                                     0.775643
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER             0.549933
# RAPE                                                  1.000000
# CUSTODIAL RAPE                                        0.127898
# OTHER RAPE                                            1.000000
# KIDNAPPING & ABDUCTION                                0.757001
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS           0.744057
# KIDNAPPING AND ABDUCTION OF OTHERS                    0.647951
# DACOITY                                               0.619120
# PREPARATION AND ASSEMBLY FOR DACOITY                  0.522920
# ROBBERY                                               0.750620
# BURGLARY                                              0.796735
# THEFT                                                 0.797338
# AUTO THEFT                                            0.732627
# OTHER THEFT                                           0.783807
# RIOTS                                                 0.661184
# CRIMINAL BREACH OF TRUST                              0.701449
# CHEATING                                              0.681986
# COUNTERFIETING                                        0.581213
# ARSON                                                 0.738468
# HURT/GREVIOUS HURT                                    0.758527
# DOWRY DEATHS                                          0.720318
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...    0.902859
# INSULT TO MODESTY OF WOMEN                            0.493751
# CRUELTY BY HUSBAND OR HIS RELATIVES                   0.774561
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES           0.244384
# CAUSING DEATH BY NEGLIGENCE                           0.730912
# OTHER IPC CRIMES                                      0.790611
# TOTAL IPC CRIMES                                      0.860514
# CRIME_LEVEL                                           0.805299
# STATE/UT_encoded                                      0.000172
# DISTRICT_encoded                                      0.174496
#
#                                                     KIDNAPPING & ABDUCTION  \
# YEAR                                                              0.074994
# MURDER                                                            0.812158
# ATTEMPT TO MURDER                                                 0.812462
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                         0.713369
# RAPE                                                              0.757015
# CUSTODIAL RAPE                                                    0.124048
# OTHER RAPE                                                        0.757001
# KIDNAPPING & ABDUCTION                                            1.000000
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                       0.984319
# KIDNAPPING AND ABDUCTION OF OTHERS                                0.851734
# DACOITY                                                           0.607352
# PREPARATION AND ASSEMBLY FOR DACOITY                              0.385827
# ROBBERY                                                           0.675160
# BURGLARY                                                          0.571062
# THEFT                                                             0.749018
# AUTO THEFT                                                        0.771524
# OTHER THEFT                                                       0.683154
# RIOTS                                                             0.630532
# CRIMINAL BREACH OF TRUST                                          0.846324
# CHEATING                                                          0.722968
# COUNTERFIETING                                                    0.623829
# ARSON                                                             0.582783
# HURT/GREVIOUS HURT                                                0.567284
# DOWRY DEATHS                                                      0.824114
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                0.628966
# INSULT TO MODESTY OF WOMEN                                        0.424449
# CRUELTY BY HUSBAND OR HIS RELATIVES                               0.744587
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                       0.221615
# CAUSING DEATH BY NEGLIGENCE                                       0.708747
# OTHER IPC CRIMES                                                  0.654288
# TOTAL IPC CRIMES                                                  0.746042
# CRIME_LEVEL                                                       0.686259
# STATE/UT_encoded                                                 -0.001361
# DISTRICT_encoded                                                  0.139654
#
#                                                     KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  \
# YEAR                                                                                   0.087115
# MURDER                                                                                 0.769808
# ATTEMPT TO MURDER                                                                      0.775176
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                                              0.710435
# RAPE                                                                                   0.744067
# CUSTODIAL RAPE                                                                         0.113345
# OTHER RAPE                                                                             0.744057
# KIDNAPPING & ABDUCTION                                                                 0.984319
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                                            1.000000
# KIDNAPPING AND ABDUCTION OF OTHERS                                                     0.745951
# DACOITY                                                                                0.529997
# PREPARATION AND ASSEMBLY FOR DACOITY                                                   0.375542
# ROBBERY                                                                                0.634595
# BURGLARY                                                                               0.543512
# THEFT                                                                                  0.719285
# AUTO THEFT                                                                             0.752644
# OTHER THEFT                                                                            0.648540
# RIOTS                                                                                  0.581930
# CRIMINAL BREACH OF TRUST                                                               0.833498
# CHEATING                                                                               0.712356
# COUNTERFIETING                                                                         0.613196
# ARSON                                                                                  0.554795
# HURT/GREVIOUS HURT                                                                     0.541276
# DOWRY DEATHS                                                                           0.798553
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                                     0.624166
# INSULT TO MODESTY OF WOMEN                                                             0.399599
# CRUELTY BY HUSBAND OR HIS RELATIVES                                                    0.747294
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                                            0.145580
# CAUSING DEATH BY NEGLIGENCE                                                            0.709914
# OTHER IPC CRIMES                                                                       0.639756
# TOTAL IPC CRIMES                                                                       0.724143
# CRIME_LEVEL                                                                            0.672727
# STATE/UT_encoded                                                                       0.017106
# DISTRICT_encoded                                                                       0.133923
#
#                                                     KIDNAPPING AND ABDUCTION OF OTHERS  \
# YEAR                                                                          0.024376
# MURDER                                                                        0.779709
# ATTEMPT TO MURDER                                                             0.764913
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                                     0.583088
# RAPE                                                                          0.647978
# CUSTODIAL RAPE                                                                0.131671
# OTHER RAPE                                                                    0.647951
# KIDNAPPING & ABDUCTION                                                        0.851734
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                                   0.745951
# KIDNAPPING AND ABDUCTION OF OTHERS                                            1.000000
# DACOITY                                                                       0.718792
# PREPARATION AND ASSEMBLY FOR DACOITY                                          0.341203
# ROBBERY                                                                       0.664104
# BURGLARY                                                                      0.541627
# THEFT                                                                         0.691395
# AUTO THEFT                                                                    0.677277
# OTHER THEFT                                                                   0.652864
# RIOTS                                                                         0.652046
# CRIMINAL BREACH OF TRUST                                                      0.719521
# CHEATING                                                                      0.613622
# COUNTERFIETING                                                                0.533864
# ARSON                                                                         0.552367
# HURT/GREVIOUS HURT                                                            0.534007
# DOWRY DEATHS                                                                  0.739465
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                            0.520673
# INSULT TO MODESTY OF WOMEN                                                    0.415563
# CRUELTY BY HUSBAND OR HIS RELATIVES                                           0.591465
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                                   0.404292
# CAUSING DEATH BY NEGLIGENCE                                                   0.567183
# OTHER IPC CRIMES                                                              0.569971
# TOTAL IPC CRIMES                                                              0.665729
# CRIME_LEVEL                                                                   0.592739
# STATE/UT_encoded                                                             -0.055952
# DISTRICT_encoded                                                              0.129465
#
#                                                     ...  \
# YEAR                                                ...
# MURDER                                              ...
# ATTEMPT TO MURDER                                   ...
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER           ...
# RAPE                                                ...
# CUSTODIAL RAPE                                      ...
# OTHER RAPE                                          ...
# KIDNAPPING & ABDUCTION                              ...
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         ...
# KIDNAPPING AND ABDUCTION OF OTHERS                  ...
# DACOITY                                             ...
# PREPARATION AND ASSEMBLY FOR DACOITY                ...
# ROBBERY                                             ...
# BURGLARY                                            ...
# THEFT                                               ...
# AUTO THEFT                                          ...
# OTHER THEFT                                         ...
# RIOTS                                               ...
# CRIMINAL BREACH OF TRUST                            ...
# CHEATING                                            ...
# COUNTERFIETING                                      ...
# ARSON                                               ...
# HURT/GREVIOUS HURT                                  ...
# DOWRY DEATHS                                        ...
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...  ...
# INSULT TO MODESTY OF WOMEN                          ...
# CRUELTY BY HUSBAND OR HIS RELATIVES                 ...
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES         ...
# CAUSING DEATH BY NEGLIGENCE                         ...
# OTHER IPC CRIMES                                    ...
# TOTAL IPC CRIMES                                    ...
# CRIME_LEVEL                                         ...
# STATE/UT_encoded                                    ...
# DISTRICT_encoded                                    ...
#
#                                                     ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# YEAR                                                                                         0.033599
# MURDER                                                                                       0.722097
# ATTEMPT TO MURDER                                                                            0.715919
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                                                    0.437241
# RAPE                                                                                         0.902847
# CUSTODIAL RAPE                                                                               0.093410
# OTHER RAPE                                                                                   0.902859
# KIDNAPPING & ABDUCTION                                                                       0.628966
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                                                  0.624166
# KIDNAPPING AND ABDUCTION OF OTHERS                                                           0.520673
# DACOITY                                                                                      0.490639
# PREPARATION AND ASSEMBLY FOR DACOITY                                                         0.426985
# ROBBERY                                                                                      0.724525
# BURGLARY                                                                                     0.852541
# THEFT                                                                                        0.790566
# AUTO THEFT                                                                                   0.710080
# OTHER THEFT                                                                                  0.787567
# RIOTS                                                                                        0.646577
# CRIMINAL BREACH OF TRUST                                                                     0.624294
# CHEATING                                                                                     0.700233
# COUNTERFIETING                                                                               0.599363
# ARSON                                                                                        0.766224
# HURT/GREVIOUS HURT                                                                           0.866868
# DOWRY DEATHS                                                                                 0.618666
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                                           1.000000
# INSULT TO MODESTY OF WOMEN                                                                   0.613482
# CRUELTY BY HUSBAND OR HIS RELATIVES                                                          0.741764
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                                                  0.127962
# CAUSING DEATH BY NEGLIGENCE                                                                  0.743904
# OTHER IPC CRIMES                                                                             0.816644
# TOTAL IPC CRIMES                                                                             0.885447
# CRIME_LEVEL                                                                                  0.856010
# STATE/UT_encoded                                                                            -0.005641
# DISTRICT_encoded                                                                             0.164022
#
#                                                     INSULT TO MODESTY OF WOMEN  \
# YEAR                                                                 -0.006613
# MURDER                                                                0.645577
# ATTEMPT TO MURDER                                                     0.593146
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                             0.511816
# RAPE                                                                  0.493752
# CUSTODIAL RAPE                                                        0.064004
# OTHER RAPE                                                            0.493751
# KIDNAPPING & ABDUCTION                                                0.424449
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                           0.399599
# KIDNAPPING AND ABDUCTION OF OTHERS                                    0.415563
# DACOITY                                                               0.337354
# PREPARATION AND ASSEMBLY FOR DACOITY                                  0.180805
# ROBBERY                                                               0.479670
# BURGLARY                                                              0.599180
# THEFT                                                                 0.594484
# AUTO THEFT                                                            0.487812
# OTHER THEFT                                                           0.621678
# RIOTS                                                                 0.369732
# CRIMINAL BREACH OF TRUST                                              0.580736
# CHEATING                                                              0.550304
# COUNTERFIETING                                                        0.598607
# ARSON                                                                 0.546289
# HURT/GREVIOUS HURT                                                    0.676994
# DOWRY DEATHS                                                          0.543664
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                    0.613482
# INSULT TO MODESTY OF WOMEN                                            1.000000
# CRUELTY BY HUSBAND OR HIS RELATIVES                                   0.575343
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                           0.030951
# CAUSING DEATH BY NEGLIGENCE                                           0.673901
# OTHER IPC CRIMES                                                      0.461029
# TOTAL IPC CRIMES                                                      0.607140
# CRIME_LEVEL                                                           0.600721
# STATE/UT_encoded                                                     -0.031935
# DISTRICT_encoded                                                      0.107562
#
#                                                     CRUELTY BY HUSBAND OR HIS RELATIVES  \
# YEAR                                                                           0.057645
# MURDER                                                                         0.709600
# ATTEMPT TO MURDER                                                              0.668873
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                                      0.544761
# RAPE                                                                           0.774559
# CUSTODIAL RAPE                                                                 0.096018
# OTHER RAPE                                                                     0.774561
# KIDNAPPING & ABDUCTION                                                         0.744587
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                                    0.747294
# KIDNAPPING AND ABDUCTION OF OTHERS                                             0.591465
# DACOITY                                                                        0.503494
# PREPARATION AND ASSEMBLY FOR DACOITY                                           0.601251
# ROBBERY                                                                        0.599226
# BURGLARY                                                                       0.662259
# THEFT                                                                          0.781829
# AUTO THEFT                                                                     0.701391
# OTHER THEFT                                                                    0.779400
# RIOTS                                                                          0.636821
# CRIMINAL BREACH OF TRUST                                                       0.729881
# CHEATING                                                                       0.820990
# COUNTERFIETING                                                                 0.712903
# ARSON                                                                          0.665340
# HURT/GREVIOUS HURT                                                             0.744282
# DOWRY DEATHS                                                                   0.599653
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                             0.741764
# INSULT TO MODESTY OF WOMEN                                                     0.575343
# CRUELTY BY HUSBAND OR HIS RELATIVES                                            1.000000
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                                    0.137279
# CAUSING DEATH BY NEGLIGENCE                                                    0.738748
# OTHER IPC CRIMES                                                               0.696639
# TOTAL IPC CRIMES                                                               0.812446
# CRIME_LEVEL                                                                    0.776982
# STATE/UT_encoded                                                               0.014378
# DISTRICT_encoded                                                               0.136774
#
#                                                     IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# YEAR                                                                                  -0.022344
# MURDER                                                                                 0.312656
# ATTEMPT TO MURDER                                                                      0.300088
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                                              0.164227
# RAPE                                                                                   0.244380
# CUSTODIAL RAPE                                                                         0.023984
# OTHER RAPE                                                                             0.244384
# KIDNAPPING & ABDUCTION                                                                 0.221615
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                                            0.145580
# KIDNAPPING AND ABDUCTION OF OTHERS                                                     0.404292
# DACOITY                                                                                0.469413
# PREPARATION AND ASSEMBLY FOR DACOITY                                                   0.232535
# ROBBERY                                                                                0.252297
# BURGLARY                                                                               0.130764
# THEFT                                                                                  0.156199
# AUTO THEFT                                                                             0.098184
# OTHER THEFT                                                                            0.182481
# RIOTS                                                                                  0.330282
# CRIMINAL BREACH OF TRUST                                                               0.190781
# CHEATING                                                                               0.106296
# COUNTERFIETING                                                                         0.107838
# ARSON                                                                                  0.209010
# HURT/GREVIOUS HURT                                                                     0.157611
# DOWRY DEATHS                                                                           0.293525
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                                     0.127962
# INSULT TO MODESTY OF WOMEN                                                             0.030951
# CRUELTY BY HUSBAND OR HIS RELATIVES                                                    0.137279
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                                            1.000000
# CAUSING DEATH BY NEGLIGENCE                                                            0.121128
# OTHER IPC CRIMES                                                                       0.194660
# TOTAL IPC CRIMES                                                                       0.200260
# CRIME_LEVEL                                                                            0.171265
# STATE/UT_encoded                                                                      -0.045497
# DISTRICT_encoded                                                                       0.072454
#
#                                                     CAUSING DEATH BY NEGLIGENCE  \
# YEAR                                                                   0.041719
# MURDER                                                                 0.799893
# ATTEMPT TO MURDER                                                      0.773900
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                              0.515726
# RAPE                                                                   0.730924
# CUSTODIAL RAPE                                                         0.115343
# OTHER RAPE                                                             0.730912
# KIDNAPPING & ABDUCTION                                                 0.708747
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                            0.709914
# KIDNAPPING AND ABDUCTION OF OTHERS                                     0.567183
# DACOITY                                                                0.563205
# PREPARATION AND ASSEMBLY FOR DACOITY                                   0.306990
# ROBBERY                                                                0.726571
# BURGLARY                                                               0.799702
# THEFT                                                                  0.840399
# AUTO THEFT                                                             0.752747
# OTHER THEFT                                                            0.838547
# RIOTS                                                                  0.579163
# CRIMINAL BREACH OF TRUST                                               0.750845
# CHEATING                                                               0.776256
# COUNTERFIETING                                                         0.795610
# ARSON                                                                  0.757987
# HURT/GREVIOUS HURT                                                     0.815417
# DOWRY DEATHS                                                           0.673405
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...                     0.743904
# INSULT TO MODESTY OF WOMEN                                             0.673901
# CRUELTY BY HUSBAND OR HIS RELATIVES                                    0.738748
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                            0.121128
# CAUSING DEATH BY NEGLIGENCE                                            1.000000
# OTHER IPC CRIMES                                                       0.771662
# TOTAL IPC CRIMES                                                       0.874983
# CRIME_LEVEL                                                            0.856989
# STATE/UT_encoded                                                       0.019168
# DISTRICT_encoded                                                       0.162506
#
#                                                     OTHER IPC CRIMES  \
# YEAR                                                        0.024421
# MURDER                                                      0.738281
# ATTEMPT TO MURDER                                           0.760012
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                   0.440495
# RAPE                                                        0.790613
# CUSTODIAL RAPE                                              0.104741
# OTHER RAPE                                                  0.790611
# KIDNAPPING & ABDUCTION                                      0.654288
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 0.639756
# KIDNAPPING AND ABDUCTION OF OTHERS                          0.569971
# DACOITY                                                     0.534896
# PREPARATION AND ASSEMBLY FOR DACOITY                        0.421605
# ROBBERY                                                     0.711764
# BURGLARY                                                    0.789832
# THEFT                                                       0.771858
# AUTO THEFT                                                  0.719604
# OTHER THEFT                                                 0.752130
# RIOTS                                                       0.748367
# CRIMINAL BREACH OF TRUST                                    0.645106
# CHEATING                                                    0.686797
# COUNTERFIETING                                              0.682606
# ARSON                                                       0.742912
# HURT/GREVIOUS HURT                                          0.827622
# DOWRY DEATHS                                                0.607397
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...          0.816644
# INSULT TO MODESTY OF WOMEN                                  0.461029
# CRUELTY BY HUSBAND OR HIS RELATIVES                         0.696639
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                 0.194660
# CAUSING DEATH BY NEGLIGENCE                                 0.771662
# OTHER IPC CRIMES                                            1.000000
# TOTAL IPC CRIMES                                            0.949782
# CRIME_LEVEL                                                 0.906028
# STATE/UT_encoded                                            0.016015
# DISTRICT_encoded                                            0.169710
#
#                                                     TOTAL IPC CRIMES  \
# YEAR                                                        0.024087
# MURDER                                                      0.847480
# ATTEMPT TO MURDER                                           0.836367
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                   0.524913
# RAPE                                                        0.860521
# CUSTODIAL RAPE                                              0.123094
# OTHER RAPE                                                  0.860514
# KIDNAPPING & ABDUCTION                                      0.746042
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 0.724143
# KIDNAPPING AND ABDUCTION OF OTHERS                          0.665729
# DACOITY                                                     0.640843
# PREPARATION AND ASSEMBLY FOR DACOITY                        0.468585
# ROBBERY                                                     0.810259
# BURGLARY                                                    0.900485
# THEFT                                                       0.909276
# AUTO THEFT                                                  0.827899
# OTHER THEFT                                                 0.898684
# RIOTS                                                       0.797224
# CRIMINAL BREACH OF TRUST                                    0.776105
# CHEATING                                                    0.810283
# COUNTERFIETING                                              0.779780
# ARSON                                                       0.831589
# HURT/GREVIOUS HURT                                          0.918007
# DOWRY DEATHS                                                0.703392
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...          0.885447
# INSULT TO MODESTY OF WOMEN                                  0.607140
# CRUELTY BY HUSBAND OR HIS RELATIVES                         0.812446
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                 0.200260
# CAUSING DEATH BY NEGLIGENCE                                 0.874983
# OTHER IPC CRIMES                                            0.949782
# TOTAL IPC CRIMES                                            1.000000
# CRIME_LEVEL                                                 0.954775
# STATE/UT_encoded                                           -0.001475
# DISTRICT_encoded                                            0.178686
#
#                                                     CRIME_LEVEL  \
# YEAR                                                   0.018724
# MURDER                                                 0.805740
# ATTEMPT TO MURDER                                      0.802921
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0.507065
# RAPE                                                   0.805303
# CUSTODIAL RAPE                                         0.110029
# OTHER RAPE                                             0.805299
# KIDNAPPING & ABDUCTION                                 0.686259
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0.672727
# KIDNAPPING AND ABDUCTION OF OTHERS                     0.592739
# DACOITY                                                0.580631
# PREPARATION AND ASSEMBLY FOR DACOITY                   0.428832
# ROBBERY                                                0.768458
# BURGLARY                                               0.856471
# THEFT                                                  0.853461
# AUTO THEFT                                             0.763570
# OTHER THEFT                                            0.852139
# RIOTS                                                  0.751839
# CRIMINAL BREACH OF TRUST                               0.726743
# CHEATING                                               0.764141
# COUNTERFIETING                                         0.743789
# ARSON                                                  0.796215
# HURT/GREVIOUS HURT                                     0.894479
# DOWRY DEATHS                                           0.680962
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...     0.856010
# INSULT TO MODESTY OF WOMEN                             0.600721
# CRUELTY BY HUSBAND OR HIS RELATIVES                    0.776982
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES            0.171265
# CAUSING DEATH BY NEGLIGENCE                            0.856989
# OTHER IPC CRIMES                                       0.906028
# TOTAL IPC CRIMES                                       0.954775
# CRIME_LEVEL                                            1.000000
# STATE/UT_encoded                                       0.008620
# DISTRICT_encoded                                       0.166416
#
#                                                     STATE/UT_encoded  \
# YEAR                                                       -0.005638
# MURDER                                                     -0.001071
# ATTEMPT TO MURDER                                           0.029266
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                   0.087459
# RAPE                                                        0.000161
# CUSTODIAL RAPE                                             -0.018677
# OTHER RAPE                                                  0.000172
# KIDNAPPING & ABDUCTION                                     -0.001361
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 0.017106
# KIDNAPPING AND ABDUCTION OF OTHERS                         -0.055952
# DACOITY                                                    -0.063467
# PREPARATION AND ASSEMBLY FOR DACOITY                        0.079476
# ROBBERY                                                     0.004490
# BURGLARY                                                   -0.037713
# THEFT                                                      -0.008067
# AUTO THEFT                                                 -0.001308
# OTHER THEFT                                                -0.011825
# RIOTS                                                      -0.023944
# CRIMINAL BREACH OF TRUST                                    0.003893
# CHEATING                                                    0.023294
# COUNTERFIETING                                              0.004507
# ARSON                                                      -0.053993
# HURT/GREVIOUS HURT                                         -0.044780
# DOWRY DEATHS                                                0.033091
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...         -0.005641
# INSULT TO MODESTY OF WOMEN                                 -0.031935
# CRUELTY BY HUSBAND OR HIS RELATIVES                         0.014378
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                -0.045497
# CAUSING DEATH BY NEGLIGENCE                                 0.019168
# OTHER IPC CRIMES                                            0.016015
# TOTAL IPC CRIMES                                           -0.001475
# CRIME_LEVEL                                                 0.008620
# STATE/UT_encoded                                            1.000000
# DISTRICT_encoded                                           -0.056341
#
#                                                     DISTRICT_encoded
# YEAR                                                        0.000089
# MURDER                                                      0.168289
# ATTEMPT TO MURDER                                           0.160100
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                   0.093739
# RAPE                                                        0.174504
# CUSTODIAL RAPE                                              0.036639
# OTHER RAPE                                                  0.174496
# KIDNAPPING & ABDUCTION                                      0.139654
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS                 0.133923
# KIDNAPPING AND ABDUCTION OF OTHERS                          0.129465
# DACOITY                                                     0.144225
# PREPARATION AND ASSEMBLY FOR DACOITY                        0.082740
# ROBBERY                                                     0.147120
# BURGLARY                                                    0.170323
# THEFT                                                       0.150440
# AUTO THEFT                                                  0.127225
# OTHER THEFT                                                 0.154911
# RIOTS                                                       0.156888
# CRIMINAL BREACH OF TRUST                                    0.141788
# CHEATING                                                    0.132026
# COUNTERFIETING                                              0.144603
# ARSON                                                       0.170924
# HURT/GREVIOUS HURT                                          0.166185
# DOWRY DEATHS                                                0.119548
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MOD...          0.164022
# INSULT TO MODESTY OF WOMEN                                  0.107562
# CRUELTY BY HUSBAND OR HIS RELATIVES                         0.136774
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES                 0.072454
# CAUSING DEATH BY NEGLIGENCE                                 0.162506
# OTHER IPC CRIMES                                            0.169710
# TOTAL IPC CRIMES                                            0.178686
# CRIME_LEVEL                                                 0.166416
# STATE/UT_encoded                                           -0.056341
# DISTRICT_encoded                                            1.000000
#
# [34 rows x 34 columns]

# %%
plt.figure(figsize=(25,15))
sns.heatmap(crime.select_dtypes(include=['number']).corr(),annot=True,cmap='icefire')
# Out:
# <Axes: >

# %% [markdown]
# Looking at the correlation matrix, we can see that some variables are highly positively correlated with each other, such as "RAPE" and "OTHER RAPE" with a correlation coefficient of 1.00. Similarly, "KIDNAPPING & ABDUCTION" and "KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS" have a high positive correlation coefficient of 0.98.

# %% [markdown]
# # Time series analysis

# %%
import statsmodels.api as sm
plt.figure(figsize=(15,8))

crime_df = pd.read_csv(r"crime.csv", parse_dates=['YEAR'], index_col=['YEAR'])

# Resample data to yearly frequency
crime_yearly = crime_df.resample('Y').sum()

# Plot the time series
plt.plot(crime_yearly.index, crime_yearly['TOTAL IPC CRIMES'])
plt.title('Total IPC Crimes over Time')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.show()

# Decompose the time series into trend, seasonality, and residuals
decomposition = sm.tsa.seasonal_decompose(crime_yearly['TOTAL IPC CRIMES'], model='additive')

# Plot the decomposition results
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(12, 7))
ax1.plot(crime_yearly.index, decomposition.observed)
ax1.set_ylabel('Observed')
ax2.plot(crime_yearly.index, decomposition.trend)
ax2.set_ylabel('Trend')
ax3.plot(crime_yearly.index, decomposition.seasonal)
ax3.set_ylabel('Seasonal')
ax4.plot(crime_yearly.index, decomposition.resid)
ax4.set_ylabel('Residual')
plt.tight_layout()
plt.show()

# Test for stationarity using the Augmented Dickey-Fuller test
adf_result = sm.tsa.stattools.adfuller(crime_yearly['TOTAL IPC CRIMES'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:', adf_result[4])
# Out:
# ADF Statistic: 2.218253427797937
# p-value: 0.9988971912058884
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}

# %%
# Plot ACF
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(crime_yearly['TOTAL IPC CRIMES'])
plt.show()

# %%
# Plot PACF
from statsmodels.graphics.tsaplots import plot_pacf
sm.graphics.tsa.plot_pacf(crime_yearly['TOTAL IPC CRIMES'], lags=5)
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lags')
plt.ylabel('Partial Autocorrelation')
plt.show()

# %%
# Estimate the autoregressive integrated moving average (ARIMA) model
model = sm.tsa.ARIMA(crime_yearly['TOTAL IPC CRIMES'], order=(1,1,1))
results = model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       TOTAL IPC CRIMES   No. Observations:                   13
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -167.382
# Date:                Sat, 07 Sep 2024   AIC                            340.764
# Time:                        18:03:54   BIC                            342.219
# Sample:                    12-31-2001   HQIC                           340.226
#                          - 12-31-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7077      0.243     -2.917      0.004      -1.183      -0.232
# ma.L1          0.7513      0.225      3.336      0.001       0.310       1.193
# sigma2      1.683e+10    2.5e-11   6.73e+20      0.000    1.68e+10    1.68e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):                 1.95
# Prob(Q):                              0.70   Prob(JB):                         0.38
# Heteroskedasticity (H):               8.95   Skew:                             0.82
# Prob(H) (two-sided):                  0.06   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.27e+36. Standard errors may be unstable.

# %%
# Plot the actual values and the predicted values
plt.figure(figsize=(15,8))
plt.plot(crime_yearly.index, crime_yearly['TOTAL IPC CRIMES'], label='Actual')
plt.plot(crime_yearly.index, results.predict(start=0, end=len(crime_yearly)-1), label='Predicted')
plt.title('Actual vs Predicted Total IPC Crimes')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.legend()
plt.show()

# %%
# Plot the actual values and the forecasted values
plt.figure(figsize=(15,8))
forecast = results.predict(start=len(crime_yearly), end=len(crime_yearly)+4)
plt.plot(crime_yearly.index, crime_yearly['TOTAL IPC CRIMES'], label='Actual')
plt.plot(forecast.index, forecast, label='Forecast')
plt.title('Actual vs Forecasted Total IPC Crimes')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.legend()
plt.show()

# %% [markdown]
# # Deep Analysis - Functions

# %% [markdown]
# ### Query Analysis: Crime Overview by Year and State

# %%
import pandas as pd

def query_analysis(year, state):
    # Filter dataset by year and state
    crime_filtered = crime[(crime['YEAR'] == year) & (crime['STATE/UT'] == state)]
    
    # Select the top 4 crimes (excluding total columns)
    crime_columns = ['MURDER', 'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER',
                     'RAPE', 'KIDNAPPING & ABDUCTION', 'THEFT', 'ROBBERY', 'DOWRY DEATHS',
                     'CRUELTY BY HUSBAND OR HIS RELATIVES', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY']
    
    # Sum the crimes for the state and year
    crime_sum = crime_filtered[crime_columns].sum().sort_values(ascending=False)
    
    # Calculate percentages for the top 4 crimes
    total_crimes = crime_filtered['TOTAL IPC CRIMES'].sum()
    top_crimes = crime_sum.head(4)
    top_crimes_percentage = (top_crimes / total_crimes) * 100
    
    # Create a report
    report = pd.DataFrame({
        'Crime': top_crimes.index,
        'Number of Cases': top_crimes.values,
        'Percentage': top_crimes_percentage.values
    })
    
    print(f"Crime Analysis for {state} in {year}")
    # print(report)
    
    return report

# Example Usage
query_analysis(2005, 'MAHARASHTRA')
# Out:
# Crime Analysis for MAHARASHTRA in 2005
#                                                Crime  Number of Cases  \
# 0                                              THEFT            93702
# 1                CRUELTY BY HUSBAND OR HIS RELATIVES            12466
# 2  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MO...             6456
# 3                                             MURDER             5242
#
#    Percentage
# 0   25.050394
# 1    3.332674
# 2    1.725954
# 3    1.401402

# %% [markdown]
# ### Graph Analysis: Visualize Crime Data by Year and Type

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def graph_analysis(year, crime_type):
    # Filter data for the given year
    crime_filtered = crime[crime['YEAR'] == year]
    
    # Plot the crime type across states
    plt.figure(figsize=(10, 6))
    sns.barplot(x='STATE/UT', y=crime_type, data=crime_filtered, palette="viridis")
    plt.title(f"{crime_type} in different States for the year {year}")
    plt.xticks(rotation=90)
    plt.ylabel('Number of Cases')
    plt.xlabel('State')
    plt.tight_layout()
    plt.show()

# Example Usage
graph_analysis(2013, 'MURDER')

# %% [markdown]
# ### Predictive Analysis: Forecast Future Crime Trends

# %%
import statsmodels.api as sm

def predictive_analysis(state, year):
    # Filter data by state
    crime_state = crime[crime['STATE/UT'] == state]
    
    # Aggregate the data yearly for total IPC crimes
    crime_state_yearly = crime_state.groupby('YEAR').sum()['TOTAL IPC CRIMES']
    
    # Fit ARIMA model for prediction
    model = sm.tsa.ARIMA(crime_state_yearly, order=(1, 1, 1))  # ARIMA(1,1,1) is an example order
    model_fit = model.fit()
    
    # Forecast future crime numbers
    forecast = model_fit.forecast(steps=5)  # Forecast for the next 5 years
    print(f"Future crime predictions for {state} starting from {year}:")
    print(forecast)
    
    return forecast

# Example Usage
predictive_analysis('MAHARASHTRA', 2013)
# Out:
# Future crime predictions for MAHARASHTRA starting from 2013:
# 13    466698.359721
# 14    466695.182529
# 15    466695.177657
# 16    466695.177649
# 17    466695.177649
# Name: predicted_mean, dtype: float64
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 13    466698.359721
# 14    466695.182529
# 15    466695.177657
# 16    466695.177649
# 17    466695.177649
# Name: predicted_mean, dtype: float64

# %% [markdown]
# ### Conclusion and Reporting with Graphs

# %%
import matplotlib.pyplot as plt

def conclusion_report(year, state):
    # Get data for the state and year
    report = query_analysis(year, state)
    
    # Plot the percentage contribution of the top 4 crimes
    plt.figure(figsize=(8, 6))
    plt.pie(report['Percentage'], labels=report['Crime'], autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
    plt.title(f"Crime Breakdown for {state} in {year}")
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()
    
    # Perform predictive analysis
    future_forecast = predictive_analysis(state, year)
    
    # Plot future predictions
    plt.figure(figsize=(10, 6))
    plt.plot(future_forecast, marker='o', linestyle='--', color='b')
    plt.title(f"Predicted Future Crimes for {state} (next 5 years)")
    plt.ylabel("Total IPC Crimes")
    plt.xlabel("Years")
    plt.grid(True)
    plt.show()

# Example Usage
conclusion_report(2013, 'MAHARASHTRA')
# Out:
# Crime Analysis for MAHARASHTRA in 2013
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Future crime predictions for MAHARASHTRA starting from 2013:
# 13    466698.359721
# 14    466695.182529
# 15    466695.177657
# 16    466695.177649
# 17    466695.177649
# Name: predicted_mean, dtype: float64

# %% [markdown]
# # Implement machine learning model

# %%
crime.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
min_val = crime['TOTAL IPC CRIMES'].min()
max_val = crime['TOTAL IPC CRIMES'].max()
range_val = (max_val - min_val) / 4
low = min_val + range_val
medium = low + range_val
high = medium + range_val

# %%
def get_crime_level(crime_count):
    if crime_count <= low:
        return 1
    elif crime_count <= medium:
        return 2
    elif crime_count <= high:
        return 3
    else:
        return 4

crime['CRIME_LEVEL'] = crime['TOTAL IPC CRIMES'].apply(get_crime_level)

# %%
crime_level_count = crime['CRIME_LEVEL'].value_counts()
crime_level_count
# Out:
# 1    9685
# 3      67
# 2      48
# 4      40
# Name: CRIME_LEVEL, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# fit and transform the STATE/UT column using the LabelEncoder
crime["STATE/UT_encoded"] = le.fit_transform(crime["STATE/UT"])

# fit and transform the DISTRICT column using the LabelEncoder
crime["DISTRICT_encoded"] = le.fit_transform(crime["DISTRICT"])

# %%
grouped_state = crime[["STATE/UT", "STATE/UT_encoded"]].groupby("STATE/UT").first()
grouped_state
# Out:
#                    STATE/UT_encoded
# STATE/UT
# A & N ISLANDS                     0
# A&N ISLANDS                       1
# ANDHRA PRADESH                    2
# ARUNACHAL PRADESH                 3
# ASSAM                             4
# BIHAR                             5
# CHANDIGARH                        6
# CHHATTISGARH                      7
# D & N HAVELI                      8
# D&N HAVELI                        9
# DAMAN & DIU                      10
# DELHI UT                         11
# GOA                              12
# GUJARAT                          13
# HARYANA                          14
# HIMACHAL PRADESH                 15
# JAMMU & KASHMIR                  16
# JHARKHAND                        17
# KARNATAKA                        18
# KERALA                           19
# LAKSHADWEEP                      20
# MADHYA PRADESH                   21
# MAHARASHTRA                      22
# MANIPUR                          23
# MEGHALAYA                        24
# MIZORAM                          25
# NAGALAND                         26
# ODISHA                           27
# PUDUCHERRY                       28
# PUNJAB                           29
# RAJASTHAN                        30
# SIKKIM                           31
# TAMIL NADU                       32
# TRIPURA                          33
# UTTAR PRADESH                    34
# UTTARAKHAND                      35
# WEST BENGAL                      36

# %%
grouped_district = crime[["DISTRICT", "DISTRICT_encoded"]].groupby("DISTRICT").first()
grouped_district
# Out:
#                    DISTRICT_encoded
# DISTRICT
# 24 PARGANAS NORTH                 0
# 24 PARGANAS SOUTH                 1
# A AND N ISLANDS                   2
# ADILABAD                          3
# AGAR                              4
# ...                             ...
# YADGIRI                         823
# YAMUNANAGAR                     824
# YAVATMAL                        825
# ZUNHEBOTO                       826
# ZZ TOTAL                        827
#
# [828 rows x 1 columns]

# %%
crime.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'CRIME_LEVEL', 'STATE/UT_encoded', 'DISTRICT_encoded'],
#       dtype='object')

# %% [markdown]
# # Linear Regression

# %%
X = crime.drop(['CRIME_LEVEL','STATE/UT', 'DISTRICT','TOTAL IPC CRIMES'], axis=1)
y = crime['TOTAL IPC CRIMES']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
lr = LinearRegression()
lr.fit(X_train,y_train)
lr_pred = lr.predict(X_test)
lr_score = lr.score(X_test, y_test)
print('Linear Regression score : ',lr_score)
print()
print('Mean_absolute_error  = ',metrics.mean_absolute_error(lr_pred,y_test))
print()
print('Mean_squared_error   = ',metrics.mean_squared_error(lr_pred,y_test))
print()
print('R2_score             = ',metrics.r2_score(lr_pred,y_test))
print()
R2 = metrics.r2_score(lr_pred,y_test)
adj_R2 = 1-((1-R2)*(len(y)-1)/(len(y)-X.shape[1]-1))
print('Adjusted_R2         = ',adj_R2)
# Out:
# Linear Regression score :  0.9999999999452605
#
# Mean_absolute_error  =  0.006192793043933714
#
# Mean_squared_error   =  0.02750475477950661
#
# R2_score             =  0.9999999999452605
#
# Adjusted_R2         =  0.9999999999450818

# %%
import statsmodels.api as sm
results = sm.OLS(y_train,X_train).fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       TOTAL IPC CRIMES   R-squared (uncentered):                   0.920
# Model:                            OLS   Adj. R-squared (uncentered):              0.920
# Method:                 Least Squares   F-statistic:                              2738.
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):                        0.00
# Time:                        22:41:17   Log-Likelihood:                         -68527.
# No. Observations:                6888   AIC:                                  1.371e+05
# Df Residuals:                    6859   BIC:                                  1.373e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0022     63.025   3.44e-05      1.000    -123.546     123.551
# x2           287.8150    432.065      0.666      0.505    -559.167    1134.797
# x3           273.0485    270.039      1.011      0.312    -256.311     802.408
# x4            47.8524    172.901      0.277      0.782    -291.087     386.792
# x5            90.9675    125.616      0.724      0.469    -155.279     337.214
# x6             0.0542     63.246      0.001      0.999    -123.928     124.037
# x7            90.9747    125.629      0.724      0.469    -155.298     337.247
# x8           128.2529     96.235      1.333      0.183     -60.397     316.903
# x9           145.1097    149.927      0.968      0.333    -148.793     439.013
# x10           51.6572    156.219      0.331      0.741    -254.581     357.895
# x11           53.8002    203.698      0.264      0.792    -345.511     453.111
# x12           44.8419    114.955      0.390      0.696    -180.506     270.190
# x13          207.5295    186.173      1.115      0.265    -157.427     572.486
# x14          828.1893    314.669      2.632      0.009     211.340    1445.038
# x15          955.1206    105.869      9.022      0.000     747.584    1162.657
# x16          681.7160    179.300      3.802      0.000     330.233    1033.199
# x17         1060.0079    184.881      5.733      0.000     697.585    1422.431
# x18          641.9557    179.205      3.582      0.000     290.658     993.254
# x19          153.6455    243.646      0.631      0.528    -323.975     631.266
# x20          702.7918    140.532      5.001      0.000     427.306     978.278
# x21           24.1682    132.111      0.183      0.855    -234.809     283.146
# x22           95.1016    132.030      0.720      0.471    -163.717     353.921
# x23         2750.6003    275.002     10.002      0.000    2211.511    3289.690
# x24           84.3212    242.725      0.347      0.728    -391.494     560.137
# x25          364.9748    263.429      1.385      0.166    -151.427     881.377
# x26          135.7866    128.124      1.060      0.289    -115.377     386.950
# x27          822.1193    197.280      4.167      0.000     435.390    1208.849
# x28            2.1616     85.444      0.025      0.980    -165.335     169.658
# x29          850.4773    210.537      4.040      0.000     437.759    1263.195
# x30         7658.5153    179.801     42.594      0.000    7306.050    8010.981
# x31           -0.0016     63.372  -2.51e-05      1.000    -124.231     124.228
# x32           -0.0022     62.705   -3.5e-05      1.000    -122.923     122.919
# ==============================================================================
# Omnibus:                    25828.580   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      13541980252.586
# Skew:                         -82.832   Prob(JB):                         0.00
# Kurtosis:                    6870.107   Cond. No.                     1.30e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 7.58e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels
name = ['Lagrange multiplier statistic', 'p-value', 
        'f-value', 'f p-value']

bp = statsmodels.stats.diagnostic.het_breuschpagan(results.resid, results.model.exog)
bp

pd.DataFrame(name, bp)
# Out:
#                                  0
# 0.0  Lagrange multiplier statistic
# 1.0                        p-value
# 0.0                        f-value
# 1.0                      f p-value

# %% [markdown]
# # Logistic Regression

# %%
X = crime.drop(['CRIME_LEVEL','STATE/UT', 'DISTRICT'], axis=1)
y = crime['CRIME_LEVEL']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
log_pred = log.predict(X_test)
log_score = log.score(X_test, y_test)
log_prob = log.predict_proba(X_test)[:, 1]
print('Logistic regression score : ',log_score)
print()
print(confusion_matrix(y_test, log_pred))
print()
print(classification_report(y_test, log_pred))
# Out:
# Logistic regression score :  0.9925474254742548
#
# [[2892    3    0    0]
#  [   1    7    2    0]
#  [   0    5   18    4]
#  [   0    3    4   13]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2895
#            2       0.39      0.70      0.50        10
#            3       0.75      0.67      0.71        27
#            4       0.76      0.65      0.70        20
#
#     accuracy                           0.99      2952
#    macro avg       0.73      0.75      0.73      2952
# weighted avg       0.99      0.99      0.99      2952

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
svm = SVC(probability=True)
svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)
svm_prob = svm.predict_proba(X_test)[:, 1] if svm.probability else None
svm_score = svm.score(X_test, y_test)
print('Support Vector Machine score : ',svm_score)
print()
print(confusion_matrix(y_test, svm_pred))
print()
print(classification_report(y_test, svm_pred))
# Out:
# Support Vector Machine score :  0.9915311653116531
#
# [[2894    1    0    0]
#  [   2    6    2    0]
#  [   9    1   17    0]
#  [   8    0    2   10]]
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      2895
#            2       0.75      0.60      0.67        10
#            3       0.81      0.63      0.71        27
#            4       1.00      0.50      0.67        20
#
#     accuracy                           0.99      2952
#    macro avg       0.89      0.68      0.76      2952
# weighted avg       0.99      0.99      0.99      2952

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)
dt_prob = dt.predict_proba(X_test)[:, 1]
dt_score = dt.score(X_test, y_test)
print('Decision tree score : ',dt_score)
print()
print(confusion_matrix(y_test, dt_pred))
print()
print(classification_report(y_test, dt_pred))
# Out:
# Decision tree score :  1.0
#
# [[2895    0    0    0]
#  [   0   10    0    0]
#  [   0    0   27    0]
#  [   0    0    0   20]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2895
#            2       1.00      1.00      1.00        10
#            3       1.00      1.00      1.00        27
#            4       1.00      1.00      1.00        20
#
#     accuracy                           1.00      2952
#    macro avg       1.00      1.00      1.00      2952
# weighted avg       1.00      1.00      1.00      2952

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
rf_prob = rf.predict_proba(X_test)[:, 1]
rf_score = rf.score(X_test, y_test)
print('Random forest score : ',rf_score)
print()
print(confusion_matrix(y_test, rf_pred))
print()
print(classification_report(y_test, rf_pred))
# Out:
# Random forest score :  0.9979674796747967
#
# [[2895    0    0    0]
#  [   0   10    0    0]
#  [   0    0   23    4]
#  [   0    0    2   18]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2895
#            2       1.00      1.00      1.00        10
#            3       0.92      0.85      0.88        27
#            4       0.82      0.90      0.86        20
#
#     accuracy                           1.00      2952
#    macro avg       0.93      0.94      0.94      2952
# weighted avg       1.00      1.00      1.00      2952

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
nb_pred = nb.predict(X_test)
nb_prob = nb.predict_proba(X_test)[:, 1]
nd_score = nb.score(X_test, y_test)
print('Naive Bayes score : ',nd_score)
print()
print(confusion_matrix(y_test, nb_pred))
print()
print(classification_report(y_test, nb_pred))
# Out:
# Naive Bayes score :  0.9800135501355014
#
# [[2850   45    0    0]
#  [   0    9    1    0]
#  [   0    3   17    7]
#  [   0    0    3   17]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99      2895
#            2       0.16      0.90      0.27        10
#            3       0.81      0.63      0.71        27
#            4       0.71      0.85      0.77        20
#
#     accuracy                           0.98      2952
#    macro avg       0.67      0.84      0.69      2952
# weighted avg       0.99      0.98      0.99      2952

# %% [markdown]
# # Clustering

# %%
X = crime.drop(['STATE/UT', 'DISTRICT','TOTAL IPC CRIMES','CRIME_LEVEL', 'STATE/UT_encoded', 'DISTRICT_encoded'], axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans

X = crime[['MURDER', 'RAPE', 'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT']]
X_scaled = scaler.fit_transform(X)

# Perform k-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X_scaled)

# Visualize clusters and cluster centers
plt.scatter(crime['THEFT'], crime['MURDER'], c=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 4], kmeans.cluster_centers_[:, 0], marker='*', c='red')
plt.xlabel('Number of Thefts')
plt.ylabel('Number of Murders')
plt.show()

# %% [markdown]
# # Hierarchical _Clustering

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
Z = linkage(X_scaled, method='ward')

# Plot dendrogram
plt.figure(figsize=(20, 8))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# Perform hierarchical clustering
hier_clust = AgglomerativeClustering(n_clusters=3)
labels = hier_clust.fit_predict(X_scaled)

# Visualize clusters
plt.scatter(crime['THEFT'], crime['MURDER'], c=labels)
plt.xlabel('Number of Thefts')
plt.ylabel('Number of Murders')
plt.show()

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(X_scaled)

# Visualize clusters
plt.scatter(crime['THEFT'], crime['MURDER'], c=dbscan.labels_)
plt.xlabel('Number of Thefts')
plt.ylabel('Number of Murders')
plt.show()
